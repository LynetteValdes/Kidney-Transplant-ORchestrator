# %%
import json
import networkx as nx
import gurobipy as gp
from gurobipy import GRB
import matplotlib.pyplot as plt

# Load data from the JSON file
with open('Kidney_Transplant_Orchestrator.json', 'r') as file:
    data = json.load(file)

# Compatibility based on blood type
donor_recipient_compatibility = {
    'O': ['O', 'A', 'B', 'AB'],
    'A': ['A', 'AB'],
    'B': ['B', 'AB'],
    'AB': ['AB']
}

# %%
# Create directed graph
G = nx.DiGraph()

# Add nodes and edges based on compatibility
counter = 0
for element in data:
    G.add_nodes_from([(counter, element)])
    counter += 1

# Create edges based on donor-recipient compatibility
for node in G.nodes:
    donors = G.nodes[node]['Donor']
    for donor in donors:
        for vertex in G.nodes:
            if node == vertex:
                continue
            recipient = G.nodes[vertex]['Recipient']
            if recipient in donor_recipient_compatibility[donor]:
                G.add_edge(node, vertex)

print('Total edges:', len(G.edges))
# Out:
# Total edges: 171996

# %%
#-------------------------------------------------------PARTICIPANT-MAXIMIZING PLAN----------------------------------------------------------------------

# %%
# ----------- FINDING 2-WAY AND 3-WAY CYCLES  ------------------

def find_2_and_3_way_cycles(G):
    """
    Finds all unique 2-way and 3-way cycles in the graph G.
    """
    cycle_2 = []
    cycle_3 = []
    H = G.to_undirected()  # Convert to undirected graph for neighbor checks

    # Initialize visited status for each directed edge
    for (i, j) in G.edges:
        G.edges[(i, j)]["visited"] = 0

    # Detect 3-way cycles
    for (i, j) in H.edges:
        for k in nx.common_neighbors(H, i, j):
            # Check if (i, j), (j, k), (k, i) form a valid 3-way cycle
            if (i, j) in G.edges and G.edges[(i, j)]["visited"] < 2:
                if (j, k) in G.edges and G.edges[(j, k)]["visited"] < 2:
                    if (k, i) in G.edges and G.edges[(k, i)]["visited"] < 2:
                        cycle = tuple(sorted([i, j, k]))  # Sort nodes to ensure uniqueness
                        if cycle not in cycle_3:  # Ensure no duplicate cycles
                            cycle_3.append(cycle)
                            # Mark edges as visited
                            G.edges[(i, j)]["visited"] += 1
                            G.edges[(j, k)]["visited"] += 1
                            G.edges[(k, i)]["visited"] += 1

    # Reset visited status for 2-way cycle detection
    for (i, j) in G.edges:
        G.edges[(i, j)]["visited"] = False

    # Detect 2-way cycles
    for (i, j) in G.edges:
        if G.edges[(i, j)]["visited"]:
            continue  # Skip if already visited
        if (j, i) in G.edges:  # Check if reciprocal edge exists
            cycle_2.append((i, j))  # Add as a 2-way cycle
            # Mark both edges as visited
            G.edges[(i, j)]["visited"] = True
            G.edges[(j, i)]["visited"] = True

    # Combine both lists into a single list of cycles
    return cycle_2 + cycle_3

# %%
# ----------- GUROBI OPTIMIZATION ----------------
# Combine 2-way and 3-way cycles 
cycles = find_2_and_3_way_cycles(G)

# Create a Gurobi model
m = gp.Model("Kidney_Exchange")

# Add binary decision variables for each cycle (2-way or 3-way)
x = m.addVars(cycles, vtype=GRB.BINARY, name="x")

# Objective: Maximize the number of participants in selected cycles
m.setObjective(gp.quicksum(x[c] * (2 if len(c) == 2 else 3) for c in cycles), GRB.MAXIMIZE)

# Constraints: Each node (donor or recipient) can participate in at most one cycle
m.addConstrs(gp.quicksum(x[c] for c in cycles if v in c) <= 1 for v in G.nodes)

# Optimize the model
m.optimize()

# Display results
if m.SolCount > 0:
    print(f"\nOptimal Solution Found:")
    print(f"Total Participants in Selected Cycles (Objective Value): {m.objVal}")

    selected_cycles = [c for c in cycles if x[c].X > 0.5]
    print("\nSelected Cycles (Donor-Recipient Pairs):")
    for cycle in selected_cycles:
        if len(cycle) == 2:
            print(f"2-Way Cycle: Donor {cycle[0]} <-> Recipient {cycle[1]}")
        elif len(cycle) == 3:
            print(f"3-Way Cycle: Donor {cycle[0]} -> Recipient {cycle[1]} -> Donor {cycle[1]} -> Recipient {cycle[2]} -> Donor {cycle[2]} -> Recipient {cycle[0]}")
else:
    print("No feasible solution found.")
# Out:
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1140G7 @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 715 rows, 32448 columns and 64896 nonzeros
# Model fingerprint: 0xd91fd067
# Variable types: 0 continuous, 32448 integer (32448 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [2e+00, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 338.0000000
# Presolve removed 354 rows and 0 columns
# Presolve time: 0.09s
# Presolved: 361 rows, 32448 columns, 64896 nonzeros
# Variable types: 0 continuous, 32448 integer (32448 binary)
#
# Starting sifting (using dual simplex for sub-problems)...
#
#     Iter     Pivots    Primal Obj      Dual Obj        Time
#        0          0     infinity     -7.2000000e+02      0s
#        1        422  -2.0000000e+01  -3.6800000e+02      0s
#
# Sifting complete
#
#
# Root relaxation: cutoff, 1170 iterations, 0.06 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       338.00000  338.00000  0.00%     -    0s
#
# Explored 1 nodes (1170 simplex iterations) in 0.26 seconds (0.16 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 338
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.380000000000e+02, best bound 3.380000000000e+02, gap 0.0000%
#
# Optimal Solution Found:
# Total Participants in Selected Cycles (Objective Value): 338.0
#
# Selected Cycles (Donor-Recipient Pairs):
# 2-Way Cycle: Donor 2 <-> Recipient 7
# 2-Way Cycle: Donor 6 <-> Recipient 9
# 2-Way Cycle: Donor 10 <-> Recipient 12
# 2-Way Cycle: Donor 14 <-> Recipient 18
# 2-Way Cycle: Donor 17 <-> Recipient 19
# 2-Way Cycle: Donor 20 <-> Recipient 24
# 2-Way Cycle: Donor 22 <-> Recipient 30
# 2-Way Cycle: Donor 23 <-> Recipient 33
# 2-Way Cycle: Donor 28 <-> Recipient 38
# 2-Way Cycle: Donor 37 <-> Recipient 52
# 2-Way Cycle: Donor 46 <-> Recipient 61
# 2-Way Cycle: Donor 50 <-> Recipient 62
# 2-Way Cycle: Donor 55 <-> Recipient 70
# 2-Way Cycle: Donor 56 <-> Recipient 75
# 2-Way Cycle: Donor 57 <-> Recipient 78
# 2-Way Cycle: Donor 58 <-> Recipient 80
# 2-Way Cycle: Donor 59 <-> Recipient 83
# 2-Way Cycle: Donor 64 <-> Recipient 84
# 2-Way Cycle: Donor 65 <-> Recipient 92
# 2-Way Cycle: Donor 67 <-> Recipient 93
# 2-Way Cycle: Donor 72 <-> Recipient 101
# 2-Way Cycle: Donor 73 <-> Recipient 112
# 2-Way Cycle: Donor 74 <-> Recipient 124
# 2-Way Cycle: Donor 76 <-> Recipient 126
# 2-Way Cycle: Donor 79 <-> Recipient 132
# 2-Way Cycle: Donor 87 <-> Recipient 136
# 2-Way Cycle: Donor 90 <-> Recipient 137
# 2-Way Cycle: Donor 96 <-> Recipient 141
# 2-Way Cycle: Donor 97 <-> Recipient 152
# 2-Way Cycle: Donor 102 <-> Recipient 154
# 2-Way Cycle: Donor 105 <-> Recipient 159
# 2-Way Cycle: Donor 106 <-> Recipient 165
# 2-Way Cycle: Donor 110 <-> Recipient 167
# 2-Way Cycle: Donor 115 <-> Recipient 168
# 2-Way Cycle: Donor 116 <-> Recipient 171
# 2-Way Cycle: Donor 117 <-> Recipient 183
# 2-Way Cycle: Donor 118 <-> Recipient 190
# 2-Way Cycle: Donor 119 <-> Recipient 191
# 2-Way Cycle: Donor 120 <-> Recipient 192
# 2-Way Cycle: Donor 123 <-> Recipient 197
# 2-Way Cycle: Donor 131 <-> Recipient 210
# 2-Way Cycle: Donor 135 <-> Recipient 217
# 2-Way Cycle: Donor 138 <-> Recipient 220
# 2-Way Cycle: Donor 140 <-> Recipient 222
# 2-Way Cycle: Donor 143 <-> Recipient 223
# 2-Way Cycle: Donor 144 <-> Recipient 229
# 2-Way Cycle: Donor 151 <-> Recipient 230
# 2-Way Cycle: Donor 153 <-> Recipient 232
# 2-Way Cycle: Donor 157 <-> Recipient 234
# 2-Way Cycle: Donor 163 <-> Recipient 235
# 2-Way Cycle: Donor 164 <-> Recipient 236
# 2-Way Cycle: Donor 169 <-> Recipient 239
# 2-Way Cycle: Donor 175 <-> Recipient 240
# 2-Way Cycle: Donor 176 <-> Recipient 241
# 2-Way Cycle: Donor 177 <-> Recipient 251
# 2-Way Cycle: Donor 180 <-> Recipient 256
# 2-Way Cycle: Donor 181 <-> Recipient 259
# 2-Way Cycle: Donor 182 <-> Recipient 275
# 2-Way Cycle: Donor 193 <-> Recipient 277
# 2-Way Cycle: Donor 194 <-> Recipient 279
# 2-Way Cycle: Donor 196 <-> Recipient 285
# 2-Way Cycle: Donor 199 <-> Recipient 287
# 2-Way Cycle: Donor 201 <-> Recipient 291
# 2-Way Cycle: Donor 202 <-> Recipient 292
# 2-Way Cycle: Donor 203 <-> Recipient 296
# 2-Way Cycle: Donor 207 <-> Recipient 297
# 2-Way Cycle: Donor 208 <-> Recipient 304
# 2-Way Cycle: Donor 211 <-> Recipient 305
# 2-Way Cycle: Donor 212 <-> Recipient 312
# 2-Way Cycle: Donor 214 <-> Recipient 321
# 2-Way Cycle: Donor 215 <-> Recipient 325
# 2-Way Cycle: Donor 221 <-> Recipient 329
# 2-Way Cycle: Donor 224 <-> Recipient 332
# 2-Way Cycle: Donor 226 <-> Recipient 333
# 2-Way Cycle: Donor 227 <-> Recipient 338
# 2-Way Cycle: Donor 237 <-> Recipient 341
# 2-Way Cycle: Donor 238 <-> Recipient 344
# 2-Way Cycle: Donor 244 <-> Recipient 346
# 2-Way Cycle: Donor 246 <-> Recipient 348
# 2-Way Cycle: Donor 252 <-> Recipient 355
# 2-Way Cycle: Donor 260 <-> Recipient 384
# 2-Way Cycle: Donor 262 <-> Recipient 385
# 2-Way Cycle: Donor 274 <-> Recipient 389
# 2-Way Cycle: Donor 276 <-> Recipient 391
# 2-Way Cycle: Donor 286 <-> Recipient 394
# 2-Way Cycle: Donor 289 <-> Recipient 395
# 2-Way Cycle: Donor 294 <-> Recipient 404
# 2-Way Cycle: Donor 299 <-> Recipient 405
# 2-Way Cycle: Donor 300 <-> Recipient 415
# 2-Way Cycle: Donor 301 <-> Recipient 419
# 2-Way Cycle: Donor 303 <-> Recipient 427
# 2-Way Cycle: Donor 307 <-> Recipient 429
# 2-Way Cycle: Donor 309 <-> Recipient 435
# 2-Way Cycle: Donor 310 <-> Recipient 438
# 2-Way Cycle: Donor 313 <-> Recipient 439
# 2-Way Cycle: Donor 316 <-> Recipient 448
# 2-Way Cycle: Donor 318 <-> Recipient 451
# 2-Way Cycle: Donor 322 <-> Recipient 453
# 2-Way Cycle: Donor 323 <-> Recipient 454
# 2-Way Cycle: Donor 324 <-> Recipient 458
# 2-Way Cycle: Donor 327 <-> Recipient 466
# 2-Way Cycle: Donor 334 <-> Recipient 467
# 2-Way Cycle: Donor 335 <-> Recipient 470
# 2-Way Cycle: Donor 336 <-> Recipient 472
# 2-Way Cycle: Donor 345 <-> Recipient 475
# 2-Way Cycle: Donor 349 <-> Recipient 477
# 2-Way Cycle: Donor 358 <-> Recipient 490
# 2-Way Cycle: Donor 359 <-> Recipient 495
# 2-Way Cycle: Donor 364 <-> Recipient 502
# 2-Way Cycle: Donor 365 <-> Recipient 504
# 2-Way Cycle: Donor 366 <-> Recipient 505
# 2-Way Cycle: Donor 367 <-> Recipient 508
# 2-Way Cycle: Donor 376 <-> Recipient 509
# 2-Way Cycle: Donor 382 <-> Recipient 513
# 2-Way Cycle: Donor 401 <-> Recipient 530
# 2-Way Cycle: Donor 402 <-> Recipient 531
# 2-Way Cycle: Donor 407 <-> Recipient 535
# 2-Way Cycle: Donor 409 <-> Recipient 539
# 2-Way Cycle: Donor 411 <-> Recipient 541
# 2-Way Cycle: Donor 417 <-> Recipient 543
# 2-Way Cycle: Donor 420 <-> Recipient 547
# 2-Way Cycle: Donor 421 <-> Recipient 548
# 2-Way Cycle: Donor 424 <-> Recipient 555
# 2-Way Cycle: Donor 428 <-> Recipient 560
# 2-Way Cycle: Donor 437 <-> Recipient 561
# 2-Way Cycle: Donor 440 <-> Recipient 565
# 2-Way Cycle: Donor 441 <-> Recipient 571
# 2-Way Cycle: Donor 443 <-> Recipient 572
# 2-Way Cycle: Donor 445 <-> Recipient 573
# 2-Way Cycle: Donor 449 <-> Recipient 578
# 2-Way Cycle: Donor 450 <-> Recipient 585
# 2-Way Cycle: Donor 455 <-> Recipient 589
# 2-Way Cycle: Donor 457 <-> Recipient 591
# 2-Way Cycle: Donor 459 <-> Recipient 595
# 2-Way Cycle: Donor 460 <-> Recipient 598
# 2-Way Cycle: Donor 462 <-> Recipient 605
# 2-Way Cycle: Donor 476 <-> Recipient 613
# 2-Way Cycle: Donor 479 <-> Recipient 614
# 2-Way Cycle: Donor 481 <-> Recipient 617
# 2-Way Cycle: Donor 483 <-> Recipient 619
# 2-Way Cycle: Donor 494 <-> Recipient 620
# 2-Way Cycle: Donor 500 <-> Recipient 623
# 2-Way Cycle: Donor 510 <-> Recipient 624
# 2-Way Cycle: Donor 515 <-> Recipient 626
# 2-Way Cycle: Donor 517 <-> Recipient 634
# 2-Way Cycle: Donor 519 <-> Recipient 636
# 2-Way Cycle: Donor 521 <-> Recipient 638
# 2-Way Cycle: Donor 523 <-> Recipient 646
# 2-Way Cycle: Donor 525 <-> Recipient 650
# 2-Way Cycle: Donor 527 <-> Recipient 654
# 2-Way Cycle: Donor 532 <-> Recipient 655
# 2-Way Cycle: Donor 534 <-> Recipient 658
# 2-Way Cycle: Donor 540 <-> Recipient 663
# 2-Way Cycle: Donor 544 <-> Recipient 664
# 2-Way Cycle: Donor 551 <-> Recipient 665
# 2-Way Cycle: Donor 564 <-> Recipient 666
# 2-Way Cycle: Donor 568 <-> Recipient 669
# 2-Way Cycle: Donor 579 <-> Recipient 675
# 2-Way Cycle: Donor 582 <-> Recipient 676
# 2-Way Cycle: Donor 583 <-> Recipient 677
# 2-Way Cycle: Donor 587 <-> Recipient 678
# 2-Way Cycle: Donor 599 <-> Recipient 689
# 2-Way Cycle: Donor 601 <-> Recipient 693
# 2-Way Cycle: Donor 602 <-> Recipient 694
# 2-Way Cycle: Donor 606 <-> Recipient 699
# 2-Way Cycle: Donor 610 <-> Recipient 701
# 2-Way Cycle: Donor 615 <-> Recipient 707
# 2-Way Cycle: Donor 618 <-> Recipient 709
# 2-Way Cycle: Donor 622 <-> Recipient 712

# %%
#----------------------------------------------------------MATCH-MAXIMIZING PLAN----------------------------------------------------------------------

# %%
def find_2_and_3_way_cycles(G):
    """
    Finds valid 2-way and 3-way cycles in the graph G.
    Returns a list of tuples representing each cycle.
    """
    cycles = []

    # Find 2-way cycles
    for (i, j) in G.edges:
        if G.has_edge(j, i) and i < j:  # Ensure no duplicates by ordering nodes
            cycles.append((i, j))

    # Find 3-way cycles
    for i in G.nodes:
        for j in G.successors(i):
            if j == i:
                continue  # Avoid self-loops
            for k in G.successors(j):
                if k == i or k == j:
                    continue  # Avoid self-loops and repeated nodes
                if G.has_edge(k, i):  # Check if it completes a 3-way cycle
                    # Only add unique 3-way cycles (sorted order)
                    cycles.append(tuple(sorted((i, j, k))))

    # Remove duplicate 3-way cycles
    cycles = list(set(cycles))
    return cycles

# %%
# ----------- GUROBI OPTIMIZATION ----------------
# Combine 2-way and 3-way cycles 
cycles = find_2_and_3_way_cycles(G)

# Create a Gurobi model
m = gp.Model("Kidney_Exchange")

# Add binary decision variables for each cycle (2-way or 3-way)
x = m.addVars(cycles, vtype=GRB.BINARY, name="x")

# Alternative Objective: Maximize the number of selected cycles (matches)
m.setObjective(gp.quicksum(x[c] for c in cycles), GRB.MAXIMIZE)


# Constraints: Each node (donor or recipient) can participate in at most one cycle
m.addConstrs(gp.quicksum(x[c] for c in cycles if v in c) <= 1 for v in G.nodes)

# Optimize the model
m.optimize()

# Display results
if m.SolCount > 0:
    print(f"\nOptimal Solution Found:")
    print(f"Total Participants in Selected Cycles (Objective Value): {m.objVal}")

    selected_cycles = [c for c in cycles if x[c].X > 0.5]
    print("\nSelected Cycles (Donor-Recipient Pairs):")
    for cycle in selected_cycles:
        if len(cycle) == 2:
            print(f"2-Way Cycle: Donor {cycle[0]} <-> Recipient {cycle[1]}")
        elif len(cycle) == 3:
            print(f"3-Way Cycle: Donor {cycle[0]} -> Recipient {cycle[1]} -> Donor {cycle[1]} -> Recipient {cycle[2]} -> Donor {cycle[2]} -> Recipient {cycle[0]}")
else:
    print("No feasible solution found.")
# Out:
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: 11th Gen Intel(R) Core(TM) i5-1140G7 @ 1.10GHz, instruction set [SSE2|AVX|AVX2|AVX512]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 715 rows, 32448 columns and 64896 nonzeros
# Model fingerprint: 0xb3379e69
# Variable types: 0 continuous, 32448 integer (32448 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 169.0000000
# Presolve removed 354 rows and 0 columns
# Presolve time: 0.11s
# Presolved: 361 rows, 32448 columns, 64896 nonzeros
# Variable types: 0 continuous, 32448 integer (32448 binary)
#
# Root relaxation: cutoff, 1083 iterations, 0.05 seconds (0.06 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       169.00000  169.00000  0.00%     -    0s
#
# Explored 1 nodes (1083 simplex iterations) in 0.26 seconds (0.19 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 1: 169
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.690000000000e+02, best bound 1.690000000000e+02, gap 0.0000%
#
# Optimal Solution Found:
# Total Participants in Selected Cycles (Objective Value): 169.0
#
# Selected Cycles (Donor-Recipient Pairs):
# 2-Way Cycle: Donor 244 <-> Recipient 509
# 2-Way Cycle: Donor 285 <-> Recipient 510
# 2-Way Cycle: Donor 260 <-> Recipient 453
# 2-Way Cycle: Donor 246 <-> Recipient 555
# 2-Way Cycle: Donor 58 <-> Recipient 504
# 2-Way Cycle: Donor 75 <-> Recipient 673
# 2-Way Cycle: Donor 336 <-> Recipient 448
# 2-Way Cycle: Donor 239 <-> Recipient 515
# 2-Way Cycle: Donor 338 <-> Recipient 494
# 2-Way Cycle: Donor 197 <-> Recipient 289
# 2-Way Cycle: Donor 7 <-> Recipient 165
# 2-Way Cycle: Donor 163 <-> Recipient 678
# 2-Way Cycle: Donor 215 <-> Recipient 279
# 2-Way Cycle: Donor 118 <-> Recipient 346
# 2-Way Cycle: Donor 618 <-> Recipient 669
# 2-Way Cycle: Donor 595 <-> Recipient 685
# 2-Way Cycle: Donor 292 <-> Recipient 684
# 2-Way Cycle: Donor 419 <-> Recipient 459
# 2-Way Cycle: Donor 18 <-> Recipient 115
# 2-Way Cycle: Donor 116 <-> Recipient 458
# 2-Way Cycle: Donor 138 <-> Recipient 217
# 2-Way Cycle: Donor 229 <-> Recipient 335
# 2-Way Cycle: Donor 19 <-> Recipient 525
# 2-Way Cycle: Donor 421 <-> Recipient 505
# 2-Way Cycle: Donor 132 <-> Recipient 402
# 2-Way Cycle: Donor 324 <-> Recipient 572
# 2-Way Cycle: Donor 136 <-> Recipient 521
# 2-Way Cycle: Donor 14 <-> Recipient 531
# 2-Way Cycle: Donor 437 <-> Recipient 634
# 2-Way Cycle: Donor 96 <-> Recipient 341
# 2-Way Cycle: Donor 439 <-> Recipient 680
# 2-Way Cycle: Donor 164 <-> Recipient 475
# 2-Way Cycle: Donor 541 <-> Recipient 583
# 2-Way Cycle: Donor 632 <-> Recipient 701
# 2-Way Cycle: Donor 310 <-> Recipient 650
# 2-Way Cycle: Donor 24 <-> Recipient 64
# 2-Way Cycle: Donor 543 <-> Recipient 629
# 2-Way Cycle: Donor 6 <-> Recipient 424
# 2-Way Cycle: Donor 78 <-> Recipient 300
# 2-Way Cycle: Donor 168 <-> Recipient 193
# 2-Way Cycle: Donor 38 <-> Recipient 120
# 2-Way Cycle: Donor 548 <-> Recipient 599
# 2-Way Cycle: Donor 55 <-> Recipient 666
# 2-Way Cycle: Donor 626 <-> Recipient 640
# 2-Way Cycle: Donor 428 <-> Recipient 655
# 2-Way Cycle: Donor 202 <-> Recipient 312
# 2-Way Cycle: Donor 80 <-> Recipient 322
# 2-Way Cycle: Donor 429 <-> Recipient 476
# 2-Way Cycle: Donor 483 <-> Recipient 712
# 2-Way Cycle: Donor 235 <-> Recipient 610
# 2-Way Cycle: Donor 97 <-> Recipient 676
# 2-Way Cycle: Donor 119 <-> Recipient 435
# 2-Way Cycle: Donor 141 <-> Recipient 194
# 2-Way Cycle: Donor 22 <-> Recipient 502
# 2-Way Cycle: Donor 93 <-> Recipient 153
# 2-Way Cycle: Donor 427 <-> Recipient 564
# 2-Way Cycle: Donor 177 <-> Recipient 389
# 2-Way Cycle: Donor 181 <-> Recipient 508
# 2-Way Cycle: Donor 327 <-> Recipient 333
# 2-Way Cycle: Donor 307 <-> Recipient 620
# 2-Way Cycle: Donor 180 <-> Recipient 256
# 2-Way Cycle: Donor 56 <-> Recipient 220
# 2-Way Cycle: Donor 135 <-> Recipient 513
# 2-Way Cycle: Donor 560 <-> Recipient 662
# 2-Way Cycle: Donor 208 <-> Recipient 210
# 2-Way Cycle: Donor 20 <-> Recipient 159
# 2-Way Cycle: Donor 70 <-> Recipient 276
# 2-Way Cycle: Donor 74 <-> Recipient 395
# 2-Way Cycle: Donor 123 <-> Recipient 287
# 2-Way Cycle: Donor 72 <-> Recipient 699
# 2-Way Cycle: Donor 226 <-> Recipient 385
# 2-Way Cycle: Donor 259 <-> Recipient 683
# 2-Way Cycle: Donor 83 <-> Recipient 457
# 2-Way Cycle: Donor 440 <-> Recipient 694
# 2-Way Cycle: Donor 151 <-> Recipient 591
# 2-Way Cycle: Donor 62 <-> Recipient 519
# 2-Way Cycle: Donor 460 <-> Recipient 565
# 2-Way Cycle: Donor 171 <-> Recipient 462
# 2-Way Cycle: Donor 277 <-> Recipient 299
# 2-Way Cycle: Donor 144 <-> Recipient 709
# 2-Way Cycle: Donor 240 <-> Recipient 417
# 2-Way Cycle: Donor 407 <-> Recipient 530
# 2-Way Cycle: Donor 344 <-> Recipient 366
# 2-Way Cycle: Donor 365 <-> Recipient 654
# 2-Way Cycle: Donor 2 <-> Recipient 602
# 2-Way Cycle: Donor 230 <-> Recipient 237
# 2-Way Cycle: Donor 59 <-> Recipient 355
# 2-Way Cycle: Donor 33 <-> Recipient 73
# 2-Way Cycle: Donor 101 <-> Recipient 207
# 2-Way Cycle: Donor 92 <-> Recipient 653
# 2-Way Cycle: Donor 481 <-> Recipient 613
# 2-Way Cycle: Donor 183 <-> Recipient 367
# 2-Way Cycle: Donor 67 <-> Recipient 192
# 2-Way Cycle: Donor 214 <-> Recipient 619
# 2-Way Cycle: Donor 286 <-> Recipient 495
# 2-Way Cycle: Donor 313 <-> Recipient 598
# 2-Way Cycle: Donor 175 <-> Recipient 664
# 2-Way Cycle: Donor 211 <-> Recipient 321
# 2-Way Cycle: Donor 251 <-> Recipient 659
# 2-Way Cycle: Donor 52 <-> Recipient 449
# 2-Way Cycle: Donor 90 <-> Recipient 152
# 2-Way Cycle: Donor 582 <-> Recipient 614
# 2-Way Cycle: Donor 223 <-> Recipient 681
# 2-Way Cycle: Donor 294 <-> Recipient 332
# 2-Way Cycle: Donor 10 <-> Recipient 573
# 2-Way Cycle: Donor 348 <-> Recipient 568
# 2-Way Cycle: Donor 37 <-> Recipient 275
# 2-Way Cycle: Donor 190 <-> Recipient 517
# 2-Way Cycle: Donor 303 <-> Recipient 394
# 2-Way Cycle: Donor 241 <-> Recipient 455
# 2-Way Cycle: Donor 470 <-> Recipient 692
# 2-Way Cycle: Donor 143 <-> Recipient 297
# 2-Way Cycle: Donor 585 <-> Recipient 615
# 2-Way Cycle: Donor 364 <-> Recipient 646
# 2-Way Cycle: Donor 345 <-> Recipient 404
# 2-Way Cycle: Donor 477 <-> Recipient 708
# 2-Way Cycle: Donor 454 <-> Recipient 697
# 2-Way Cycle: Donor 57 <-> Recipient 472
# 2-Way Cycle: Donor 304 <-> Recipient 349
# 2-Way Cycle: Donor 318 <-> Recipient 405
# 2-Way Cycle: Donor 601 <-> Recipient 693
# 2-Way Cycle: Donor 196 <-> Recipient 415
# 2-Way Cycle: Donor 84 <-> Recipient 359
# 2-Way Cycle: Donor 420 <-> Recipient 658
# 2-Way Cycle: Donor 110 <-> Recipient 617
# 2-Way Cycle: Donor 234 <-> Recipient 252
# 2-Way Cycle: Donor 236 <-> Recipient 274
# 2-Way Cycle: Donor 201 <-> Recipient 438
# 2-Way Cycle: Donor 30 <-> Recipient 182
# 2-Way Cycle: Donor 534 <-> Recipient 624
# 2-Way Cycle: Donor 140 <-> Recipient 296
# 2-Way Cycle: Donor 212 <-> Recipient 707
# 2-Way Cycle: Donor 443 <-> Recipient 589
# 2-Way Cycle: Donor 450 <-> Recipient 605
# 2-Way Cycle: Donor 167 <-> Recipient 667
# 2-Way Cycle: Donor 157 <-> Recipient 329
# 2-Way Cycle: Donor 76 <-> Recipient 124
# 2-Way Cycle: Donor 199 <-> Recipient 689
# 2-Way Cycle: Donor 232 <-> Recipient 637
# 2-Way Cycle: Donor 305 <-> Recipient 334
# 2-Way Cycle: Donor 571 <-> Recipient 587
# 2-Way Cycle: Donor 131 <-> Recipient 665
# 2-Way Cycle: Donor 203 <-> Recipient 675
# 2-Way Cycle: Donor 479 <-> Recipient 677
# 2-Way Cycle: Donor 169 <-> Recipient 636
# 2-Way Cycle: Donor 87 <-> Recipient 663
# 2-Way Cycle: Donor 9 <-> Recipient 191
# 2-Way Cycle: Donor 137 <-> Recipient 376
# 2-Way Cycle: Donor 222 <-> Recipient 409
# 2-Way Cycle: Donor 411 <-> Recipient 466
# 2-Way Cycle: Donor 578 <-> Recipient 579
# 2-Way Cycle: Donor 301 <-> Recipient 539
# 2-Way Cycle: Donor 382 <-> Recipient 638
# 2-Way Cycle: Donor 65 <-> Recipient 126
# 2-Way Cycle: Donor 61 <-> Recipient 625
# 2-Way Cycle: Donor 23 <-> Recipient 467
# 2-Way Cycle: Donor 325 <-> Recipient 401
# 2-Way Cycle: Donor 527 <-> Recipient 535
# 2-Way Cycle: Donor 106 <-> Recipient 291
# 2-Way Cycle: Donor 451 <-> Recipient 540
# 2-Way Cycle: Donor 28 <-> Recipient 384
# 2-Way Cycle: Donor 154 <-> Recipient 710
# 2-Way Cycle: Donor 490 <-> Recipient 606
# 2-Way Cycle: Donor 500 <-> Recipient 623
# 2-Way Cycle: Donor 551 <-> Recipient 561
# 2-Way Cycle: Donor 105 <-> Recipient 391
# 2-Way Cycle: Donor 12 <-> Recipient 176
# 2-Way Cycle: Donor 112 <-> Recipient 224
# 2-Way Cycle: Donor 46 <-> Recipient 547
